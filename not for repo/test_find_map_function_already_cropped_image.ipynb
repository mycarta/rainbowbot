# %%
import matplotlib.pyplot as plt
% matplotlib inline

# %%
import mycarta_imtools as mci

# %%
im = mci.find_map('https://github.com/mycarta/rainbowbot/raw/master/stuff4matching_cmap_notebooks/cropped_map.png')

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
plt.imshow(im)
ax.xaxis.set_ticks([])
ax.yaxis.set_ticks([])
plt.show()
