# %%
import matplotlib.pyplot as plt
% matplotlib inline

# %%
import mycarta_imtools as mci

# %%
im1 = mci.find_map('http://www.cgg.com/data//1/rec_docs/1168_uruguay_seismic1.jpg')
im2 = mci.find_map('http://www.cgg.com/data//1/rec_docs/1168_uruguay_seismic1.jpg', opt=True)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
plt.imshow(im1)
ax.xaxis.set_ticks([])
ax.yaxis.set_ticks([])
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
plt.imshow(im2)
ax.xaxis.set_ticks([])
ax.yaxis.set_ticks([])
plt.show()
