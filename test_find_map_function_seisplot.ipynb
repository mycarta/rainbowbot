# %%
import matplotlib.pyplot as plt
% matplotlib inline

# %%
import mycarta_imtools as mci

# %%
im1 = mci.find_map('https://github.com/mycarta/rainbowbot/raw/master/stuff4matching_cmap_notebooks/seisplot.png')
im2 = mci.find_map('https://github.com/mycarta/rainbowbot/raw/master/stuff4matching_cmap_notebooks/seisplot.png', opt=True)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
plt.imshow(im1)
ax.xaxis.set_ticks([])
ax.yaxis.set_ticks([])
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
plt.imshow(im2)
ax.xaxis.set_ticks([])
ax.yaxis.set_ticks([])
plt.show()
